# %%
import matplotlib.pyplot as plt
plt.style.use('default')
# %config InlineBackend.figure_format = 'svg'

# %%
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

# %%
fig = plt.plot(x, y)

# %%
plt.plot(x, y)
plt.xlabel('$x$') # Merker x-aksen
plt.ylabel('$f(x)$') # Merker y-aksen
plt.title('En tittel') #Tittel
plt.plot(x, y, '-.', label='$f(x)=x^2$')
plt.legend() # Infoboksen øverst i hjørnet. Bruker data fra label
plt.show()

# %% [markdown]
# Øke nøyaktigheten

# %%
x = [x/100 for x in range(0, 401)]

# %%
y = [y_i**2 for y_i in x]

# %%
plt.plot(x,y)

# %%
def f(x):
    return x**2

# %%
y = [f(xi) for xi in x]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Nå skal vi bruke numpy-array

# %%
import numpy as np

# %%
x = np.linspace(0, 4, 400)

# %%
plt.plot(x,f(x))

# %%
def g(x):
    return -x**2 + 10

# %%
plt.plot(x, f(x), label='$f(x)=x^2$')
plt.plot(x, g(x), label='$g(x)=-x^2+10$')
plt.legend()
