# %%
import numpy as np
import matplotlib.pyplot as plt
mm = plt.imread('mm.jpg')

# %%
plt.figure(figsize=(14,12))
plt.imshow(mm)
plt.show()

# %%
mm=np.array(mm)

# %%
mm.shape
# Out:
# (560, 840, 3)

# %%
mmd = mm

# %%
mm
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [135, 240,  96],
#         [136, 240, 101],
#         [137, 240, 105]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [134, 236,  98],
#         [134, 236, 101],
#         [135, 236, 104]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [134, 234, 102],
#         [135, 234, 105],
#         [138, 234, 108]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
for y in range(mm.shape[0]-1):
    for x in range(mm.shape[1]-1):
        mmd[y][x][0] = (mm[y][x+1][0]-mm[y][x][0])
# Out:
# /Users/madsor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in ubyte_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
