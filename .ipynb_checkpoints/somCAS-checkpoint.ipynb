# %%
import numpy as np
from sympy import *
init_printing()

# %%
x = symbols('x')
b = symbols('b')
pi = symbols('pi')

# %%
I_1 = Integral(sin(pi * x), (x, 0, b))
I_1
# Out:
# b
# ⌠
# ⎮ sin(π⋅x) dx
# ⌡
# 0

# %%
I_1.doit()
# Out:
# ⎧  cos(b⋅π)   1
# ⎪- ──────── + ─  for π > -∞ ∧ π < ∞ ∧ π ≠ 0
# ⎨     π       π
# ⎪
# ⎩      0                 otherwise

# %%
solveset(I_1.doit(), b, domain=S.Reals)
# Out:
# ⎧            ⎛ 2⋅ⅈ⋅b⋅π      ⅈ⋅b⋅π    ⎞  -ⅈ⋅b⋅π    ⎫
# ⎪            ⎝ℯ        - 2⋅ℯ      + 1⎠⋅ℯ          ⎪
# ⎨b | b ∊ ℝ ∧ ───────────────────────────────── = 0⎬
# ⎪                            2                    ⎪
# ⎩                                                 ⎭

# %%
x = symbols('x')
a = symbols('a')
b = symbols('b')

# %%
f = -x**2+(a+b)*x-a*b
f
# Out:
#         2
# -a⋅b - x  + x⋅(a + b)

# %%
g = 2*x**2-2*(a+b)*x+2*a*b
g
# Out:
#            2
# 2⋅a⋅b + 2⋅x  - x⋅(2⋅a + 2⋅b)

# %%
A_1 = factor(Integral(f,a,b).doit())
A_1
# Out:
# -a⋅b⋅(-a + 2⋅x)⋅(-b + 2⋅x)
# ───────────────────────────
#              4

# %%
A_2 = factor(Integral(g,a,b).doit())
A_2
# Out:
# a⋅b⋅(-a + 2⋅x)⋅(-b + 2⋅x)
# ─────────────────────────
#             2

# %%
A_1 - A_2
# Out:
# -3⋅a⋅b⋅(-a + 2⋅x)⋅(-b + 2⋅x)
# ─────────────────────────────
#               4

# %%
A_1/A_2
# Out:
# -1/2

# %%
b = 2*a
b
# Out:
# 2⋅a

# %%
f = -x**2+(a+b)*x-a*b
g = 2*x**2-2*(a+b)*x+2*a*b

# %%
i_f = Integral((f-g),(x,a,b))
i_f
# Out:
# 2⋅a
#  ⌠
#  ⎮  ⎛     2              2⎞
#  ⎮  ⎝- 6⋅a  + 9⋅a⋅x - 3⋅x ⎠ dx
#  ⌡
#  a

# %%
solveset(i_f.doit()-10,a, domain=S.Reals)
# Out:
# ⎧3 ____⎫
# ⎨╲╱ 20 ⎬
# ⎩      ⎭
